# %%
import re
import pandas as pd

# %%
import os
import glob

# 目標資料夾
log_dir = os.path.join('..', 'outputs', 'logs')

# 找出所有 .txt 檔案的完整路徑
txt_paths = glob.glob(os.path.join(log_dir, '*.txt'))

file_list = []
# 印出檔名（不包含路徑）
for path in txt_paths:
    file_list.append(os.path.basename(path))

file_list.sort()
file_list
# Out:
# ['log2025-07-26 02:59:33.260799.txt']

# %%
from datetime import datetime

# Get current date and time
now = datetime.now()

print("Current date and time:", now)
# Out:
# Current date and time: 2025-07-26 03:05:46.651878

# %%
import os
import glob
import re
import pandas as pd

# 1. 取得所有 .txt log 檔
log_dir   = os.path.join('..', 'outputs', 'logs')
file_list = sorted(glob.glob(os.path.join(log_dir, '*.txt')))

# 2. 準備 regex
method_pattern = re.compile(r'(Defense Method|Normal Method)')
state_pattern  = re.compile(r'以下：(?P<state>未擾動|擾動)')
metric_pattern = re.compile(
    r'Mean Absolute Error:\s*(?P<mae>[\d\.]+).*?'
    r'Root Mean Squared Error:\s*(?P<rmse>[\d\.]+)',
    re.DOTALL
)
meta_pattern   = re.compile(
    r'dataset_name:\s*(?P<dataset>[^,]+),\s*'
    r'epsilon:\s*(?P<epsilon>[^,]+),\s*'
    r'attack_method:\s*(?P<attack>[^,]+),\s*'
    r'adversarial_model_name:\s*(?P<adv_model>\S+)'
)

# 3. 逐檔解析
rows = []
for file_path in file_list:
    fn = os.path.basename(file_path)
    with open(file_path, encoding='utf-8') as f:
        text = f.read()

    current_method = None
    current_state  = None
    current_meta   = {}

    for i, line in enumerate(text.splitlines()):
        # 解析 metadata
        m_meta = meta_pattern.search(line)
        if m_meta:
            current_meta = {
                'dataset_name': m_meta.group('dataset'),
                'epsilon': m_meta.group('epsilon'),
                'attack_method': m_meta.group('attack'),
                'adversarial_model_name': m_meta.group('adv_model'),
            }
            continue

        # 解析方法
        m = method_pattern.search(line)
        if m:
            current_method = m.group(1).replace(' Method', '')
            continue

        # 解析狀態
        s = state_pattern.search(line)
        if s:
            current_state = s.group('state')
            continue

        # 解析指標
        block = "\n".join(text.splitlines()[i:i+5])
        mm = metric_pattern.search(block)
        if mm and current_method and current_state and current_meta:
            row = {
                'file': fn,
                'method': current_method,
                'state': current_state,
                'mae': float(mm.group('mae')),
                'rmse': float(mm.group('rmse')),
            }
            row.update(current_meta)
            rows.append(row)

# 4. 合併為 DataFrame
df = pd.DataFrame(rows)

# 5. 分組計算平均
summary = (
    df
    .groupby(
        ['file',
         'dataset_name','epsilon','attack_method','adversarial_model_name',
         'method','state'],
        as_index=False
    )[['mae','rmse']]
    .mean()
)

# 6. 輸出：完整表格
print(summary.to_string(index=False))
save_summary_csv(summary)
print('已儲存 summary_metrics.csv')
# Out:
#                              file     dataset_name epsilon attack_method adversarial_model_name  method state       mae      rmse
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT Defense    擾動 11.620770 17.324139
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT Defense   未擾動  9.847956 15.545058
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT  Normal    擾動 16.714030 22.527016
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT  Normal   未擾動  8.964369 13.493565
# 已儲存 summary_metrics.csv

# %%
import os
import glob
import re
import pandas as pd

# 1. 取得所有 .txt log 檔
log_dir   = os.path.join('..', 'outputs', 'logs')
file_list = sorted(glob.glob(os.path.join(log_dir, '*.txt')))

# 2. 準備 regex
method_pattern = re.compile(r'(Defense Method|Normal Method)')
state_pattern  = re.compile(r'以下：(?P<state>未擾動|擾動)')
metric_pattern = re.compile(
    r'Mean Absolute Error:\s*(?P<mae>[\d\.]+).*?'
    r'Root Mean Squared Error:\s*(?P<rmse>[\d\.]+)',
    re.DOTALL
)
meta_pattern   = re.compile(
    r'dataset_name:\s*(?P<dataset>[^,]+),\s*'
    r'epsilon:\s*(?P<epsilon>[^,]+),\s*'
    r'attack_method:\s*(?P<attack>[^,]+),\s*'
    r'adversarial_model_name:\s*(?P<adv_model>\S+)'
)

# 3. 逐檔解析
rows = []
for file_path in file_list:
    fn = os.path.basename(file_path)
    with open(file_path, encoding='utf-8') as f:
        text = f.read()

    current_method = None
    current_state  = None
    current_meta   = {}

    for i, line in enumerate(text.splitlines()):
        # 解析 metadata
        m_meta = meta_pattern.search(line)
        if m_meta:
            current_meta = {
                'dataset_name': m_meta.group('dataset'),
                'epsilon': m_meta.group('epsilon'),
                'attack_method': m_meta.group('attack'),
                'adversarial_model_name': m_meta.group('adv_model'),
            }
            continue

        # 解析方法
        m = method_pattern.search(line)
        if m:
            current_method = m.group(1).replace(' Method', '')
            continue

        # 解析狀態
        s = state_pattern.search(line)
        if s:
            current_state = s.group('state')
            continue

        # 解析指標
        block = "\n".join(text.splitlines()[i:i+5])
        mm = metric_pattern.search(block)
        if mm and current_method and current_state and current_meta:
            row = {
                'file': fn,
                'method': current_method,
                'state': current_state,
                'mae': float(mm.group('mae')),
                'rmse': float(mm.group('rmse')),
            }
            row.update(current_meta)
            rows.append(row)

# 4. 合併為 DataFrame
df = pd.DataFrame(rows)

# 5. 分組計算平均
summary = (
    df
    .groupby(
        ['file',
         'dataset_name','epsilon','attack_method','adversarial_model_name',
         'method','state'],
        as_index=False
    )[['mae','rmse']]
    .mean()
)

# 6. 輸出：完整表格
print(summary.to_string(index=False))
save_summary_csv(summary)
print('已儲存 summary_metrics.csv')
# Out:
#                              file     dataset_name epsilon attack_method adversarial_model_name  method state       mae      rmse
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT Defense    擾動 11.620770 17.324139
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT Defense   未擾動  9.847956 15.545058
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT  Normal    擾動 16.714030 22.527016
# log2025-07-26 02:59:33.260799.txt campus_processed     0.1          FGSM                     AT  Normal   未擾動  8.964369 13.493565
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 91
#      89 # 6. 輸出：完整表格
#      90 print(summary.to_string(index=False))
# ---> 91 save_summary_csv(summary)
#      92 print('已儲存 summary_metrics.csv')
#
# NameError: name 'save_summary_csv' is not defined

# %%
def save_summary_csv(summary, base_path='../outputs/logs'):
    """
    Saves the summary DataFrame to a timestamped folder as a CSV.

    Args:
        summary (pd.DataFrame): The DataFrame to save.
        base_path (str): Base directory where the logs will be stored.
    """
    now = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
    output_dir = os.path.join(base_path, now)
    os.makedirs(output_dir, exist_ok=True)
    
    output_file = os.path.join(output_dir, 'summary_metrics.csv')
    summary.to_csv(output_file, index=False, encoding='utf-8-sig')
